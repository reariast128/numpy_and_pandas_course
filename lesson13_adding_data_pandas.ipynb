# %% [markdown]
# # Agregar o eliminar datos en Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv')
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# ## Eliminar columnas con ``DataFrame.drop()``
#
# ``DataFrame.drop(column, axis)`` devuelve el DataFrame removiendo la columna especificada en el eje especificado.

# %%
df_to_work = df.copy()
df_to_work.drop('Genre', axis=1)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year
# 0                    JJ Smith          4.7    17350      8  2016
# 1                Stephen King          4.6     2052     22  2011
# 2          Jordan B. Peterson          4.7    18979     15  2018
# 3               George Orwell          4.7    21424      6  2017
# 4    National Geographic Kids          4.8     7665     12  2019
# ..                        ...          ...      ...    ...   ...
# 545               Jeff Kinney          4.9     9413      8  2019
# 546               Jen Sincero          4.7    14331      8  2016
# 547               Jen Sincero          4.7    14331      8  2017
# 548               Jen Sincero          4.7    14331      8  2018
# 549               Jen Sincero          4.7    14331      8  2019
#
# [550 rows x 6 columns]

# %% [markdown]
# Sin embargo, no la elimina del DataFrame en trabajo.

# %%
df_to_work.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Para eliminar la columna en cuestión, pasamos el argumento ``inplace=True``.

# %%
df_to_work.drop('Genre', axis=1, inplace=True)
df_to_work.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year
# 0                  JJ Smith          4.7    17350      8  2016
# 1              Stephen King          4.6     2052     22  2011
# 2        Jordan B. Peterson          4.7    18979     15  2018
# 3             George Orwell          4.7    21424      6  2017
# 4  National Geographic Kids          4.8     7665     12  2019

# %% [markdown]
# Y para eliminar varias columnas a la vez, podemos pasar los nombres mediante una secuencia.

# %%
df_to_work.drop(['Author', 'User Rating'], axis=1)
# Out:
#                                                   Name  Reviews  Price  Year  \
# 0                        10-Day Green Smoothie Cleanse    17350      8  2016
# 1                                    11/22/63: A Novel     2052     22  2011
# 2              12 Rules for Life: An Antidote to Chaos    18979     15  2018
# 3                               1984 (Signet Classics)    21424      6  2017
# 4    5,000 Awesome Facts (About Everything!) (Natio...     7665     12  2019
# ..                                                 ...      ...    ...   ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)     9413      8  2019
# 546  You Are a Badass: How to Stop Doubting Your Gr...    14331      8  2016
# 547  You Are a Badass: How to Stop Doubting Your Gr...    14331      8  2017
# 548  You Are a Badass: How to Stop Doubting Your Gr...    14331      8  2018
# 549  You Are a Badass: How to Stop Doubting Your Gr...    14331      8  2019
#
#            Genre
# 0    Non Fiction
# 1        Fiction
# 2    Non Fiction
# 3        Fiction
# 4    Non Fiction
# ..           ...
# 545      Fiction
# 546  Non Fiction
# 547  Non Fiction
# 548  Non Fiction
# 549  Non Fiction
#
# [550 rows x 5 columns]

# %% [markdown]
# ## Borrar filas con ``DataFrame.drop()``
#
# El método es el mismo, solo que ahora pasamos el índice de la fila, y pasamos el eje donde está ubicada.

# %%
df_to_work = df.copy()

# %%
df_to_work.drop(0, axis=0)
# Out:
#                                                   Name  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5         George R. R. Martin          4.4    12643     11  2011      Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [549 rows x 7 columns]

# %%
df_to_work.drop([1, 2, 3, 4], axis=0)
# Out:
#                                                   Name               Author  \
# 0                        10-Day Green Smoothie Cleanse             JJ Smith
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                       A Gentleman in Moscow: A Novel          Amor Towles
# 8        A Higher Loyalty: Truth, Lies, and Leadership          James Comey
# ..                                                 ...                  ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)          Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...          Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...          Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...          Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...          Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 0            4.7    17350      8  2016  Non Fiction
# 5            4.4    12643     11  2011      Fiction
# 6            4.7    19735     30  2014      Fiction
# 7            4.7    19699     15  2017      Fiction
# 8            4.7     5983      3  2018  Non Fiction
# ..           ...      ...    ...   ...          ...
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction
#
# [546 rows x 7 columns]

# %%
df_to_work.drop([5, 6, 7, 8], axis=0, inplace=True)
df_to_work
# Out:
#                                                   Name            Author  \
# 0                        10-Day Green Smoothie Cleanse          JJ Smith
# 9                            A Man Called Ove: A Novel   Fredrik Backman
# 10                           A Man Called Ove: A Novel   Fredrik Backman
# 11   A Patriot's History of the United States: From...  Larry Schweikart
# 12                             A Stolen Life: A Memoir     Jaycee Dugard
# ..                                                 ...               ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)       Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 0            4.7    17350      8  2016  Non Fiction
# 9            4.6    23848      8  2016      Fiction
# 10           4.6    23848      8  2017      Fiction
# 11           4.6      460      2  2010  Non Fiction
# 12           4.6     4149     32  2011  Non Fiction
# ..           ...      ...    ...   ...          ...
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction
#
# [542 rows x 7 columns]

# %% [markdown]
# ## Agregar nuevas columnas

# %% [markdown]
# Esto lo hacemos como si quisiéramos crear una nueva llave-valor en un diccionario.

# %%
df_to_work['New Column'] = pd.NA
df_to_work
# Out:
#                                                   Name            Author  \
# 0                        10-Day Green Smoothie Cleanse          JJ Smith
# 9                            A Man Called Ove: A Novel   Fredrik Backman
# 10                           A Man Called Ove: A Novel   Fredrik Backman
# 11   A Patriot's History of the United States: From...  Larry Schweikart
# 12                             A Stolen Life: A Memoir     Jaycee Dugard
# ..                                                 ...               ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)       Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre New Column
# 0            4.7    17350      8  2016  Non Fiction        NaN
# 9            4.6    23848      8  2016      Fiction        NaN
# 10           4.6    23848      8  2017      Fiction        NaN
# 11           4.6      460      2  2010  Non Fiction        NaN
# 12           4.6     4149     32  2011  Non Fiction        NaN
# ..           ...      ...    ...   ...          ...        ...
# 545          4.9     9413      8  2019      Fiction        NaN
# 546          4.7    14331      8  2016  Non Fiction        NaN
# 547          4.7    14331      8  2017  Non Fiction        NaN
# 548          4.7    14331      8  2018  Non Fiction        NaN
# 549          4.7    14331      8  2019  Non Fiction        NaN
#
# [542 rows x 8 columns]

# %% [markdown]
# Al asignar los valores mediante una secuencia, la secuencia tiene que tener la misma cantidad de registros que tiene el DataFrame, si no, generará un error.

# %%
try:
    df_to_work['New2'] = [1, 2]
except ValueError as e:
    print('Error:', e)
# Out:
# Error: Length of values (2) does not match length of index (542)

# %% [markdown]
# Podemos, por ejemplo, asignar a la nueva columna datos generados con Numpy.

# %%
import numpy as np

# %%
df_to_work['New2'] = np.arange(0, 542)
df_to_work.head()
# Out:
#                                                  Name            Author  \
# 0                       10-Day Green Smoothie Cleanse          JJ Smith
# 9                           A Man Called Ove: A Novel   Fredrik Backman
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
# 12                            A Stolen Life: A Memoir     Jaycee Dugard
#
#     User Rating  Reviews  Price  Year        Genre New Column  New2      New3
# 0           4.7    17350      8  2016  Non Fiction       <NA>     0  0.000000
# 9           4.6    23848      8  2016      Fiction       <NA>     1  0.092421
# 10          4.6    23848      8  2017      Fiction       <NA>     2  0.184843
# 11          4.6      460      2  2010  Non Fiction       <NA>     3  0.277264
# 12          4.6     4149     32  2011  Non Fiction       <NA>     4  0.369686

# %%
df_to_work['New3'] = np.linspace(0, 50, 542)
df_to_work.head()
# Out:
#                                                  Name            Author  \
# 0                       10-Day Green Smoothie Cleanse          JJ Smith
# 9                           A Man Called Ove: A Novel   Fredrik Backman
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
# 12                            A Stolen Life: A Memoir     Jaycee Dugard
#
#     User Rating  Reviews  Price  Year        Genre New Column  New2      New3
# 0           4.7    17350      8  2016  Non Fiction       <NA>     0  0.000000
# 9           4.6    23848      8  2016      Fiction       <NA>     1  0.092421
# 10          4.6    23848      8  2017      Fiction       <NA>     2  0.184843
# 11          4.6      460      2  2010  Non Fiction       <NA>     3  0.277264
# 12          4.6     4149     32  2011  Non Fiction       <NA>     4  0.369686

# %% [markdown]
# ## Agregar filas con DataFrame.concat()

# %% [markdown]
# Traeré algunos datos desde el DataFrame original.

# %%
split1 = df.copy()[:100]
split2 = df.copy()[100:]
concatenated_df = pd.concat((split1, split2))
concatenated_df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]
